# %%
#pip install opencv-contrib-python-headless

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import torch
from torch import Tensor
from torch.autograd import Variable
from torchvision.utils import make_grid
from torch import nn

# %%
# import os

# def load_images_from_folder(from_folder):
#     images = []
#     index=0
#     for filename in os.listdir(from_folder):
#         img = cv2.imread(os.path.join(from_folder,filename))
#         img = cv2.resize(img,(512,512))
#         if index <35:
#             path = 'C:/Users/User/Desktop/Inovako/Dataset/Train/'
#             name = filename + mode
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Train/' , f'{index}_{mode}.jpg' ), img)
#             img_90_cw = cv2.rotate(img, rotateCode=cv2.ROTATE_90_CLOCKWISE)
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Train/' , f'{index}_{mode}_90_cw.jpg' ), img_90_cw)
#             img_90_ccw = cv2.rotate(img, rotateCode=cv2.ROTATE_90_COUNTERCLOCKWISE)
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Train/' , f'{index}_{mode}_90_ccw.jpg' ), img_90_ccw)
#             img_180 = cv2.rotate(img, rotateCode=cv2.ROTATE_180)
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Train/' , f'{index}_{mode}_180.jpg' ), img_180)

#             img_flip = cv2.flip(img,0)
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Train/' , f'{index}_{mode}_flip.jpg' ), img_flip)
#             img_90_cw_flip = cv2.flip(img_90_cw,0)
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Train/' , f'{index}_{mode}_90_cw_flip.jpg' ), img_90_cw_flip)
#             img_90_ccw_flip = cv2.flip(img_90_ccw,0)
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Train/' , f'{index}_{mode}_90_ccw_flip.jpg' ), img_90_ccw_flip)
#             img_180_flip = cv2.flip(img_180,0)
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Train/' , f'{index}_{mode}_180_flip.jpg' ), img_180_flip)
        
#         else:
#             cv2.imwrite(os.path.join('C:/Users/User/Desktop/Inovako/Dataset/Test/' , f'{index}_{mode}.jpg' ), img)
#         index +=1

        # img = Tensor(img)
        # img_90_cw = Tensor(img_90_cw)
        # img_90_ccw = Tensor(img_90_ccw)
        # img_180 = Tensor(img_180)
        # img_flip = Tensor(img_flip)
        # img_90_cw_flip = Tensor(img_90_cw_flip)
        # img_90_ccw_flip = Tensor(img_90_ccw_flip)
        # img_180_flip = Tensor(img_180_flip)
        # if img is not None:
        #     images.append(img)
        #     images.append(img_90_cw)
        #     images.append(img_90_ccw)
        #     images.append(img_180)
        #     images.append(img_flip)
        #     images.append(img_90_cw_flip)
        #     images.append(img_90_ccw_flip)
        #     images.append(img_180_flip)
    # return images

# %%
# car_folder = 'C:/Users/User/Desktop/Inovako/Dataset/Cars/'
# cars = load_images_from_folder('C',car_folder)

# dinosaur_folder = 'C:/Users/User/Desktop/Inovako/Dataset/Dinosaurs/'
# dinosaurs = load_images_from_folder('D',dinosaur_folder)

# ship_folder = 'C:/Users/User/Desktop/Inovako/Dataset/Ships/'
# ships = load_images_from_folder('S',ship_folder)

# %%
# from torch.utils.data import DataLoader

# cars_dataloaders = DataLoader(cars)

# labeling_training = []
# labeling_test = []
# for num,i in enumerate(cars_dataloaders):
#     if (num%8 ==0) & (num >=280):
#         labeling_test.append([0,i[0]])
#     elif num<280:
#         labeling_training.append([0,i[0]]) # 0 means cars

# dinosaurs_dataloaders = DataLoader(dinosaurs)

# for num,i in enumerate(dinosaurs_dataloaders):
#     if (num%8 ==0) & (num >=280):
#         labeling_test.append([1,i[0]])
#     elif num<280:
#         labeling_training.append([1,i[0]]) # 1 label means dinosaurs

# ships_dataloaders = DataLoader(ships)

# for num,i in enumerate(ships_dataloaders):
#     if (num%8 ==0) & (num >=280):
#         labeling_test.append([2,i[0]])
#     elif num<280:
#         labeling_training.append([2,i[0]]) #2 means ships

# training_dataset = DataLoader(labeling_training,batch_size=batch_size,shuffle=True)
# test_dataset = DataLoader(labeling_test,shuffle=True)
